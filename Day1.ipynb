# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivek751992/PySpark/blob/Develop/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark

# %%
import pyspark

# %%
import pandas as pd
type(pd.read_csv('/content/test1.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('NewDemo').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://97b7fceb86a8:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>NewDemo</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv('/content/test1.csv')

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string]

# %%
df_pyspark.show()
# Out:
# +--------+---+----------+------+
# |     _c0|_c1|       _c2|   _c3|
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
dy_pyspark = spark.read.option('header','true').csv('/content/test1.csv')

# %%
type(dy_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
dy_pyspark.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
dy_pyspark.head(3)
# Out:
# [Row(Name='Ben', age='31', Experience='10', Salary='30000'),
#  Row(Name='Srikanth', age='30', Experience='8', Salary='25000'),
#  Row(Name='Sunny', age='29', Experience='4', Salary='20000')]

# %%
dy_pyspark.head()
# Out:
# Row(Name='Ben', age='31', Experience='10', Salary='30000')
