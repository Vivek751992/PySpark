# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivek751992/PySpark/blob/Develop/Day1_Ex_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://4cafa0318c93:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_ps=spark.read.csv('/content/test1.csv',header=True,inferSchema=True)
#df_ps=spark.read.option('header','true').csv('/content/test1.csv',inferSchema=True)

# %%
df_ps
# Out:
# DataFrame[Name: string, age: int, Experience: int, Salary: int]

# %%
df_ps.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df_ps.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df_ps.head(3)
# Out:
# [Row(Name='Ben', age=31, Experience=10, Salary=30000),
#  Row(Name='Srikanth', age=30, Experience=8, Salary=25000),
#  Row(Name='Sunny', age=29, Experience=4, Salary=20000)]

# %%
df_ps.select(['Name','Experience']).show()
# Out:
# +--------+----------+
# |    Name|Experience|
# +--------+----------+
# |     Ben|        10|
# |Srikanth|         8|
# |   Sunny|         4|
# |    Paul|         3|
# |  Harish|         1|
# |   Shiva|         2|
# +--------+----------+

# %%
df_ps.select('Name').show()
# Out:
# +--------+
# |    Name|
# +--------+
# |     Ben|
# |Srikanth|
# |   Sunny|
# |    Paul|
# |  Harish|
# |   Shiva|
# +--------+

# %%
df_ps.select(['Name','Experience']).show()
# Out:
# +--------+----------+
# |    Name|Experience|
# +--------+----------+
# |     Ben|        10|
# |Srikanth|         8|
# |   Sunny|         4|
# |    Paul|         3|
# |  Harish|         1|
# |   Shiva|         2|
# +--------+----------+

# %%
df_ps.select(['Name','Experience']).show(3)
# Out:
# +--------+----------+
# |    Name|Experience|
# +--------+----------+
# |     Ben|        10|
# |Srikanth|         8|
# |   Sunny|         4|
# +--------+----------+
# only showing top 3 rows

# %%
df_ps.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df_ps.describe().show()
# Out:
# +-------+-----+------------------+-----------------+------------------+
# |summary| Name|               age|       Experience|            Salary|
# +-------+-----+------------------+-----------------+------------------+
# |  count|    6|                 6|                6|                 6|
# |   mean| NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev| NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|  Ben|                21|                1|             15000|
# |    max|Sunny|                31|               10|             30000|
# +-------+-----+------------------+-----------------+------------------+

# %%
# adding new column in data frame
df_ps=df_ps.withColumn('Experience after 2 years',df_ps['Experience']+2)

# %%
df_ps.show()
# Out:
# +--------+---+----------+------+------------------------+
# |    Name|age|Experience|Salary|Experience after 2 years|
# +--------+---+----------+------+------------------------+
# |     Ben| 31|        10| 30000|                      12|
# |Srikanth| 30|         8| 25000|                      10|
# |   Sunny| 29|         4| 20000|                       6|
# |    Paul| 24|         3| 20000|                       5|
# |  Harish| 21|         1| 15000|                       3|
# |   Shiva| 23|         2| 18000|                       4|
# +--------+---+----------+------+------------------------+

# %%
df_ps=df_ps.drop('Experience after 2 years')

# %%
df_ps.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+
